# %% [markdown]
# # CSE527 Homework 3 - Part 3
# **Due date: 23:59 on Nov 26, 2023**
#
#
# ## Description
# ---
# Segmentation has been recently gaining more popularity in the field of computer vision. In this homework you will be implementing a standard UNet model to perform semantic segmentation. While transofrmer based architectures have demostrated impressive perfromance in semantic/instance segmentation, it's important to be familiar with other architectures commonly used for semantic segmentation.
#
# You will use the same dataset that you have used in part 2 of this homework, but the output of the model here is a class level segmentation mask.
#
# Input of the model will be an RGB image (3xHxW) and output will be a boolean mask (HxW).
#
# | Input Image      | Output Mask (class:horse) |
# | ----------- | ----------- |
# | ![Input Image](https://drive.google.com/uc?id=1BqmNxzV4t5MFQHjBFizlI1p9xlEatXiz)| ![Output Image](https://drive.google.com/uc?id=1NCW95D8JDBNsgzfFNa14ZiV_SiCpBPIv)|
#
#
# Read the paper: [U-Net: Convolutional Networks for Biomedical Image Segmentation
# ](https://arxiv.org/abs/1505.04597) to understand the structure of UNet models, what they are composed of, and how to build them.
#
# Also you should refer to this github repo to understand the implementations of a UNet: [milesial/Pytorch-UNet](https://github.com/milesial/Pytorch-UNet) . Specifically refer to unet/unet_model.py to gain understanding of the convolutional blocks, and skip connections.
#
# In this part you will be designing UNet architecture simmilar to it but with specific changes.

# %% [markdown]
# ## Code
# ---

# %%
HW3_ROOT_PATH = '/gdrive/My Drive/' + 'CSE527/Segireddy_RutwikReddy_115936140_hw3/' #'YOUR HOMEWORK3 PATH HERE'
PATH_TO_PART3 = HW3_ROOT_PATH + 'part3/'
PATH_TO_COCO = HW3_ROOT_PATH + 'coco/'

# %% [markdown]
# You will be using this code [unet.zip](https://drive.google.com/file/d/1p2tMMUfF2vfcr3QHipJx0XyiBOMWoMNM/view?usp=sharing) to complete your work. This code contains all the tools for loading dataset, training the newtorks, loss methods and evaluation metrics.
#
#
# To pull this code into your drive, you have to first add the zip file as shortcut to current working directory (PATH_TO_PART3 above). To do this, open the above link and click on "Add shortcut to Drive" button (drive symbol with a plus) and navigate to working PATH_TO_PART3 directory and add shortcut.
#
#
# We will use the same dataset that you have used in the Part 2 : [coco.zip dataset](https://drive.google.com/file/d/1GVyxYHwVgiG9z_Sn46wslT_2n65DLZRw/view?usp=sharing). Put this in the root of your hw3 HW3_ROOT_PATH. If you have this extracted to some path you can re-use the it.

# %%
from google.colab import drive
drive.mount('/gdrive')
# CD into root of your homework2 part3 directory
# %cd -q $HW3_ROOT_PATH
# !mkdir -p '{PATH_TO_PART3}'
# %cd $PATH_TO_PART3
# Out:
# Mounted at /gdrive
# /gdrive/My Drive/CSE527/Segireddy_RutwikReddy_115936140_hw3/part3

# %%
# !ls
# Out:
# CSE527_23F_HW3_P3.ipynb  unet  unet.zip

# %%
# !pip install -U 'git+https://github.com/cocodataset/cocoapi.git#subdirectory=PythonAPI'
# Out:
# Collecting git+https://github.com/cocodataset/cocoapi.git#subdirectory=PythonAPI
#   Cloning https://github.com/cocodataset/cocoapi.git to /tmp/pip-req-build-btdn2x1x
#   Running command git clone --filter=blob:none --quiet https://github.com/cocodataset/cocoapi.git /tmp/pip-req-build-btdn2x1x
#   Resolved https://github.com/cocodataset/cocoapi.git to commit 8c9bcc3cf640524c4c20a9c40e89cb6a2f2fa0e9
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: setuptools>=18.0 in /usr/local/lib/python3.10/dist-packages (from pycocotools==2.0) (67.7.2)
# Requirement already satisfied: cython>=0.27.3 in /usr/local/lib/python3.10/dist-packages (from pycocotools==2.0) (3.0.5)
# Requirement already satisfied: matplotlib>=2.1.0 in /usr/local/lib/python3.10/dist-packages (from pycocotools==2.0) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools==2.0) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools==2.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools==2.0) (4.44.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools==2.0) (1.4.5)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools==2.0) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools==2.0) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools==2.0) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools==2.0) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools==2.0) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=2.1.0->pycocotools==2.0) (1.16.0)
# Building wheels for collected packages: pycocotools
#   Building wheel for pycocotools (setup.py) ... done
#   Created wheel for pycocotools: filename=pycocotools-2.0-cp310-cp310-linux_x86_64.whl size=375459 sha256=884445392e6eb212ff305dd051a4398063e9c9bdfd7a44ec662f2ad9c9d422aa
#   Stored in directory: /tmp/pip-ephem-wheel-cache-swo2y4y2/wheels/39/61/b4/480fbddb4d3d6bc34083e7397bc6f5d1381f79acc68e9f3511
# Successfully built pycocotools
# Installing collected packages: pycocotools
#   Attempting uninstall: pycocotools
#     Found existing installation: pycocotools 2.0.7
#     Uninstalling pycocotools-2.0.7:
#       Successfully uninstalled pycocotools-2.0.7
# Successfully installed pycocotools-2.0

# %%
# !unzip -n ../coco.zip -d ..
# !unzip -n unet.zip

# %%
# %cd -q unet
# !ls
# Out:
# coco.py  concat_checkpoint.pth	images	main.py  __pycache__  transforms.py  unet.py  util

# %% [markdown]
# ### Load helper method

# %%
import matplotlib.pyplot as plt
import os
import numpy as np

def show_images(folder_path):
    image_paths = [os.path.join(folder_path, f) for f in os.listdir(folder_path) if os.path.isfile(os.path.join(folder_path, f))]
    image_paths = image_paths[:50]
    rows = 5
    cols = 10
    fig, axes = plt.subplots(rows, cols, figsize=(15, 8))
    for i, image_path in enumerate(image_paths):
        image = plt.imread(image_path)
        row = int(i / cols)
        col = i % cols
        axes[row, col].imshow(image)
        axes[row, col].set_title(os.path.basename(image_path))
        axes[row, col].axis('off')
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## Training
# ---
# You will use main.py for training, evaluating and visualizing.

# %%
# !python main.py --help
# Out:
# device cuda
# usage: main.py [-h] [--coco_path COCO_PATH] [--batch_size BATCH_SIZE] [--epochs EPOCHS] [--eval]
#                [--load_pretrained] [--skip {concat,sum}] [--checkpoint CHECKPOINT]
#
# Train a segmentation model on COCO data.
#
# options:
#   -h, --help            show this help message and exit
#   --coco_path COCO_PATH
#                         Path to COCO dataset directory.
#   --batch_size BATCH_SIZE
#                         Batch size for training.
#   --epochs EPOCHS       Epochs for training.
#   --eval                Whether to evaluate the model on the validation set.
#   --load_pretrained     Whether to evaluate the model on the validation set.
#   --skip {concat,sum}   Skip connection strategy: either concatenation (concat) or summation
#                         (sum).
#   --checkpoint CHECKPOINT
#                         Path to checkpoint file.

# %% [markdown]
# ##Implement UNet (15 points)
# ---
#
#
# `unet.py` contains two classes `UNet()` and `SumUNet()`, both are implementations of `torch.nn.Module()`.
#
# You need to complete the methods `UNet:__init__()` and `UNet:forward()` to implement a segmentation architecture that processes input of shape `N x 3 x H x W` (N is batch size) and will output a mask of shape `N x 1 x H x W`
#
# ###Requirements
# 1. Encoder part of the UNet will be made of pytorch Resnet's layers 1 to 4.
#
#     https://pytorch.org/vision/main/_modules/torchvision/models/resnet.html
#
#     Essentially, your UNet's encoder will be using `torchvision.models.resnet`'s `layer1, layer2, layer3, layer4` for downsampling.
#
# 2. When argument `load_pretrained_encoder_layers` of __init__() is set to true, the layers will be initialized with the pretrained weights. You can use the default pre-trained weights provided by pytorch.
#
# 3. As described in the paper or above repo, `concatenation` operations will be done for the skip connections. (in the upcoming section, you will instead use summation)
#
#
# Note:
# - You are recommended to size your model under 25M paramenters. As more parameters will hurt the trainig time and even effeciency.
# - For the decoder section (later half), you will not be able to use any pre-trained weights, so you will use randomly initialized blocks (that you will design on your own). Each block usually have layers of `[Conv, BatchNorm, ReLu]`
# - You need not use any ReLU on the last mask output layer.
#
# Hint:
# - chose a [resnet](https://pytorch.org/vision/main/_modules/torchvision/models/resnet.html) size
# - understand the `In` channels & `Out` channels of each layer of your chosen resnet()
# - build decoder layers so that they will work along the above 4 layers
# - conclude how to use the skip connections. ( you will using `concatenation`).
# - complete the forward() method
# - use print(x.shape) statements to understand the flow of tensors
#
# Log reference: [log](https://drive.google.com/file/d/1ZGd-ciOKkajri0GEOwc-uJDBjGJHJdNY/view?usp=drive_link)
#
# Aim for mIoU more than 0.35. You may not be penalized for low perfromance of your model.

# %%
# !python main.py --skip concat --coco_path "{PATH_TO_COCO}"
# Out:
# device cuda
# Namespace(coco_path='/gdrive/My Drive/CSE527/Segireddy_RutwikReddy_115936140_hw3/coco/', batch_size=20, epochs=20, eval=False, load_pretrained=False, skip='concat', checkpoint='concat_checkpoint.pth')
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# loading annotations into memory...
# Done (t=0.41s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.21s)
# creating index...
# index created!
# Epoch: [0]  [ 0/25]  eta: 0:05:30    time: 13.2067  data: 5.3138  max mem: 818
# Epoch: [0]  [10/25]  eta: 0:01:07    time: 4.4778  data: 3.6931  max mem: 926
# Epoch: [0]  [20/25]  eta: 0:00:20    time: 3.5973  data: 3.5232  max mem: 927
# Epoch: [0]  [24/25]  eta: 0:00:03    time: 3.5642  data: 3.4902  max mem: 927
# Epoch: [0] Total time: 0:01:39 (3.9784 s / it)
# train: dice: 0.817719, bce: 0.459598, loss: 0.577778
# LR 0.0005
# Epoch: [0]  [0/3]  eta: 0:00:10    time: 3.5525  data: 3.4800  max mem: 927
# Epoch: [0]  [2/3]  eta: 0:00:02    time: 2.7298  data: 2.6653  max mem: 927
# Epoch: [0] Total time: 0:00:08 (2.7302 s / it)
# val: dice: 0.831434, bce: 0.395797, loss: 0.539557, mIoU: 0.001328, mDice: 0.002556
# saving best model to concat_checkpoint.pth
# 1m 48s
# Epoch: [1]  [ 0/25]  eta: 0:00:13    time: 0.5559  data: 0.4828  max mem: 927
# Epoch: [1]  [10/25]  eta: 0:00:11    time: 0.7394  data: 0.6773  max mem: 927
# Epoch: [1]  [20/25]  eta: 0:00:03    time: 0.6705  data: 0.6132  max mem: 927
# Epoch: [1]  [24/25]  eta: 0:00:00    time: 0.6256  data: 0.5695  max mem: 927
# Epoch: [1] Total time: 0:00:16 (0.6499 s / it)
# train: dice: 0.747126, bce: 0.360942, loss: 0.488383
# LR 0.0005
# Epoch: [1]  [0/3]  eta: 0:00:00    time: 0.3186  data: 0.2699  max mem: 927
# Epoch: [1]  [2/3]  eta: 0:00:00    time: 0.2533  data: 0.2106  max mem: 927
# Epoch: [1] Total time: 0:00:00 (0.2536 s / it)
# val: dice: 0.682978, bce: 0.335102, loss: 0.449901, mIoU: 0.281094, mDice: 0.393693
# saving best model to concat_checkpoint.pth
# 0m 17s
# Epoch: [2]  [ 0/25]  eta: 0:00:23    time: 0.9484  data: 0.8766  max mem: 927
# Epoch: [2]  [10/25]  eta: 0:00:11    time: 0.7611  data: 0.7037  max mem: 927
# Epoch: [2]  [20/25]  eta: 0:00:03    time: 0.6390  data: 0.5846  max mem: 928
# Epoch: [2]  [24/25]  eta: 0:00:00    time: 0.5886  data: 0.5345  max mem: 928
# Epoch: [2] Total time: 0:00:16 (0.6414 s / it)
# train: dice: 0.714225, bce: 0.351704, loss: 0.471336
# LR 0.0005
# Epoch: [2]  [0/3]  eta: 0:00:00    time: 0.3062  data: 0.2575  max mem: 928
# Epoch: [2]  [2/3]  eta: 0:00:00    time: 0.3006  data: 0.2577  max mem: 928
# Epoch: [2] Total time: 0:00:00 (0.3012 s / it)
# val: dice: 0.702611, bce: 0.307452, loss: 0.437854, mIoU: 0.253709, mDice: 0.366399
# saving best model to concat_checkpoint.pth
# 0m 17s
# Epoch: [3]  [ 0/25]  eta: 0:00:20    time: 0.8272  data: 0.7515  max mem: 928
# Epoch: [3]  [10/25]  eta: 0:00:10    time: 0.7114  data: 0.6523  max mem: 928
# Epoch: [3]  [20/25]  eta: 0:00:03    time: 0.6373  data: 0.5810  max mem: 928
# Epoch: [3]  [24/25]  eta: 0:00:00    time: 0.5863  data: 0.5304  max mem: 928
# Epoch: [3] Total time: 0:00:15 (0.6322 s / it)
# train: dice: 0.695244, bce: 0.343123, loss: 0.459323
# LR 0.0005
# Epoch: [3]  [0/3]  eta: 0:00:01    time: 0.4383  data: 0.3895  max mem: 928
# Epoch: [3]  [2/3]  eta: 0:00:00    time: 0.3416  data: 0.2989  max mem: 928
# Epoch: [3] Total time: 0:00:01 (0.3420 s / it)
# val: dice: 0.673214, bce: 0.311400, loss: 0.430799, mIoU: 0.305782, mDice: 0.430580
# saving best model to concat_checkpoint.pth
# 0m 17s
# Epoch: [4]  [ 0/25]  eta: 0:00:20    time: 0.8234  data: 0.7497  max mem: 928
# Epoch: [4]  [10/25]  eta: 0:00:10    time: 0.6846  data: 0.6269  max mem: 928
# Epoch: [4]  [20/25]  eta: 0:00:03    time: 0.6171  data: 0.5605  max mem: 928
# Epoch: [4]  [24/25]  eta: 0:00:00    time: 0.5789  data: 0.5237  max mem: 928
# Epoch: [4] Total time: 0:00:15 (0.6264 s / it)
# train: dice: 0.681533, bce: 0.328064, loss: 0.444708
# LR 0.0005
# Epoch: [4]  [0/3]  eta: 0:00:01    time: 0.4066  data: 0.3509  max mem: 928
# Epoch: [4]  [2/3]  eta: 0:00:00    time: 0.3339  data: 0.2829  max mem: 928
# Epoch: [4] Total time: 0:00:01 (0.3344 s / it)
# val: dice: 0.714624, bce: 0.324652, loss: 0.453342, mIoU: 0.173791, mDice: 0.270262
# 0m 17s
# Epoch: [5]  [ 0/25]  eta: 0:00:20    time: 0.8119  data: 0.7386  max mem: 928
# Epoch: [5]  [10/25]  eta: 0:00:10    time: 0.6680  data: 0.6035  max mem: 928
# Epoch: [5]  [20/25]  eta: 0:00:03    time: 0.5978  data: 0.5397  max mem: 928
# Epoch: [5]  [24/25]  eta: 0:00:00    time: 0.5601  data: 0.5049  max mem: 928
# Epoch: [5] Total time: 0:00:15 (0.6087 s / it)
# Epoch: [8] Total time: 0:00:01 (0.3408 s / it)
# val: dice: 0.742744, bce: 0.315606, loss: 0.456561, mIoU: 0.089842, mDice: 0.151002
# 0m 17s
# Epoch: [9]  [ 0/25]  eta: 0:00:19    time: 0.7969  data: 0.7446  max mem: 928
# Epoch: [9]  [10/25]  eta: 0:00:08    time: 0.5858  data: 0.5307  max mem: 928
# Epoch: [9]  [20/25]  eta: 0:00:02    time: 0.5722  data: 0.5180  max mem: 928
# Epoch: [9]  [24/25]  eta: 0:00:00    time: 0.6185  data: 0.5633  max mem: 928
# Epoch: [9] Total time: 0:00:15 (0.6171 s / it)
# train: dice: 0.662151, bce: 0.318861, loss: 0.432147
# LR 0.0005
# Epoch: [9]  [0/3]  eta: 0:00:01    time: 0.4299  data: 0.3803  max mem: 928
# Epoch: [9]  [2/3]  eta: 0:00:00    time: 0.3489  data: 0.3055  max mem: 928
# Epoch: [9] Total time: 0:00:01 (0.3494 s / it)
# val: dice: 0.645193, bce: 0.317032, loss: 0.425325, mIoU: 0.370193, mDice: 0.496993
# 0m 16s
# Epoch: [10]  [ 0/25]  eta: 0:00:21    time: 0.8698  data: 0.8156  max mem: 928
# Epoch: [10]  [10/25]  eta: 0:00:08    time: 0.5629  data: 0.5095  max mem: 928
# Epoch: [10]  [20/25]  eta: 0:00:02    time: 0.5446  data: 0.4907  max mem: 928
# Epoch: [10]  [24/25]  eta: 0:00:00    time: 0.6006  data: 0.5442  max mem: 928
# Epoch: [10] Total time: 0:00:14 (0.5998 s / it)
# train: dice: 0.670580, bce: 0.325236, loss: 0.439200
# LR 0.0005
# Epoch: [10]  [0/3]  eta: 0:00:01    time: 0.4280  data: 0.3705  max mem: 928
# Epoch: [10]  [2/3]  eta: 0:00:00    time: 0.3445  data: 0.2943  max mem: 928
# Epoch: [10] Total time: 0:00:01 (0.3453 s / it)
# val: dice: 0.662391, bce: 0.289344, loss: 0.412450, mIoU: 0.292892, mDice: 0.416839
# saving best model to concat_checkpoint.pth
# 0m 16s
# Epoch: [11]  [ 0/25]  eta: 0:00:20    time: 0.8009  data: 0.7293  max mem: 928
# Epoch: [11]  [10/25]  eta: 0:00:08    time: 0.5699  data: 0.5128  max mem: 928
# Epoch: [11]  [20/25]  eta: 0:00:03    time: 0.5946  data: 0.5400  max mem: 928
# Epoch: [11]  [24/25]  eta: 0:00:00    time: 0.6450  data: 0.5900  max mem: 928
# Epoch: [11] Total time: 0:00:15 (0.6358 s / it)
# train: dice: 0.647814, bce: 0.307236, loss: 0.419626
# LR 0.0005
# Epoch: [11]  [0/3]  eta: 0:00:01    time: 0.4159  data: 0.3662  max mem: 928
# Epoch: [11]  [2/3]  eta: 0:00:00    time: 0.3401  data: 0.2965  max mem: 928
# Epoch: [11] Total time: 0:00:01 (0.3406 s / it)
# val: dice: 0.667446, bce: 0.293105, loss: 0.416637, mIoU: 0.253048, mDice: 0.370359
# 0m 17s
# Epoch: [12]  [ 0/25]  eta: 0:00:14    time: 0.5808  data: 0.5286  max mem: 928
# Epoch: [12]  [10/25]  eta: 0:00:08    time: 0.5466  data: 0.4917  max mem: 928
# Epoch: [12]  [20/25]  eta: 0:00:02    time: 0.5682  data: 0.5141  max mem: 928
# Epoch: [12]  [24/25]  eta: 0:00:00    time: 0.6203  data: 0.5635  max mem: 928
# Epoch: [12] Total time: 0:00:15 (0.6061 s / it)
# train: dice: 0.640780, bce: 0.307035, loss: 0.417171
# LR 0.0005
# Epoch: [12]  [0/3]  eta: 0:00:01    time: 0.4265  data: 0.3689  max mem: 928
# Epoch: [12]  [2/3]  eta: 0:00:00    time: 0.3401  data: 0.2898  max mem: 928
# Epoch: [12] Total time: 0:00:01 (0.3406 s / it)
# val: dice: 0.646654, bce: 0.304454, loss: 0.417380, mIoU: 0.276250, mDice: 0.391668
# 0m 16s
# Epoch: [13]  [ 0/25]  eta: 0:00:14    time: 0.5777  data: 0.5179  max mem: 928
# Epoch: [13]  [10/25]  eta: 0:00:08    time: 0.5531  data: 0.4992  max mem: 928
# Epoch: [13]  [20/25]  eta: 0:00:02    time: 0.5806  data: 0.5264  max mem: 928
# Epoch: [13]  [24/25]  eta: 0:00:00    time: 0.6338  data: 0.5783  max mem: 928
# Epoch: [13] Total time: 0:00:15 (0.6180 s / it)
# train: dice: 0.642117, bce: 0.315809, loss: 0.423491
# LR 0.0005
# Epoch: [13]  [0/3]  eta: 0:00:01    time: 0.4110  data: 0.3619  max mem: 928
# Epoch: [13]  [2/3]  eta: 0:00:00    time: 0.3280  data: 0.2856  max mem: 928
# Epoch: [13] Total time: 0:00:00 (0.3284 s / it)
# val: dice: 0.646474, bce: 0.285400, loss: 0.404554, mIoU: 0.289154, mDice: 0.409092
# saving best model to concat_checkpoint.pth
# 0m 17s
# Epoch: [14]  [ 0/25]  eta: 0:00:14    time: 0.5734  data: 0.5219  max mem: 928
# Epoch: [14]  [10/25]  eta: 0:00:08    time: 0.5485  data: 0.4961  max mem: 928
# Epoch: [14]  [20/25]  eta: 0:00:03    time: 0.6079  data: 0.5538  max mem: 928
# Epoch: [14]  [24/25]  eta: 0:00:00    time: 0.6592  data: 0.6031  max mem: 928
# Epoch: [14] Total time: 0:00:15 (0.6383 s / it)
# train: dice: 0.634248, bce: 0.304488, loss: 0.413309
# LR 0.0005
# Epoch: [14]  [0/3]  eta: 0:00:00    time: 0.3110  data: 0.2609  max mem: 928
# Epoch: [14]  [2/3]  eta: 0:00:00    time: 0.2488  data: 0.2051  max mem: 928
# Epoch: [14] Total time: 0:00:00 (0.2492 s / it)
# val: dice: 0.633463, bce: 0.285236, loss: 0.400151, mIoU: 0.320125, mDice: 0.443457
# saving best model to concat_checkpoint.pth
# 0m 17s
# Epoch: [15]  [ 0/25]  eta: 0:00:14    time: 0.5625  data: 0.5092  max mem: 928
# Epoch: [15]  [10/25]  eta: 0:00:08    time: 0.5333  data: 0.4803  max mem: 928
# train: dice: 0.630819, bce: 0.301760, loss: 0.410350
# LR 0.0005
# Epoch: [18]  [0/3]  eta: 0:00:00    time: 0.3103  data: 0.2623  max mem: 928
# Epoch: [18]  [2/3]  eta: 0:00:00    time: 0.2570  data: 0.2147  max mem: 928
# Epoch: [18] Total time: 0:00:00 (0.2574 s / it)
# val: dice: 0.638443, bce: 0.289205, loss: 0.404453, mIoU: 0.273652, mDice: 0.388388
# 0m 16s
# Epoch: [19]  [ 0/25]  eta: 0:00:14    time: 0.5617  data: 0.5102  max mem: 928
# Epoch: [19]  [10/25]  eta: 0:00:08    time: 0.5471  data: 0.4927  max mem: 928
# Epoch: [19]  [20/25]  eta: 0:00:03    time: 0.6028  data: 0.5478  max mem: 928
# Epoch: [19]  [24/25]  eta: 0:00:00    time: 0.6409  data: 0.5847  max mem: 928
# Epoch: [19] Total time: 0:00:15 (0.6214 s / it)
# train: dice: 0.623958, bce: 0.298481, loss: 0.405888
# LR 5e-05
# Epoch: [19]  [0/3]  eta: 0:00:01    time: 0.3485  data: 0.2871  max mem: 928
# Epoch: [19]  [2/3]  eta: 0:00:00    time: 0.2772  data: 0.2217  max mem: 928
# Epoch: [19] Total time: 0:00:00 (0.2775 s / it)
# val: dice: 0.611765, bce: 0.280045, loss: 0.389513, mIoU: 0.355509, mDice: 0.482970
# saving best model to concat_checkpoint.pth
# 0m 17s
# Best val loss: 0.389513

# %% [markdown]
# ### Evaluation
# To just run the evaluation or to produce the predicted masks in the `images/` folder, you need to run the main.py with --eval.
# Note that this will load the latest stored checkpoint corresponding to the --skip flag that you have provided.

# %%
# !python main.py --skip concat --coco_path "{PATH_TO_COCO}" --eval
# Out:
# device cuda
# Namespace(coco_path='/gdrive/My Drive/CSE527/Segireddy_RutwikReddy_115936140_hw3/coco/', batch_size=20, epochs=20, eval=True, load_pretrained=False, skip='concat', checkpoint='concat_checkpoint.pth')
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# Performance on validation dataset: mIoU:0.35550880432128906 , mDice:0.48297032713890076

# %% [markdown]
# For concatenation skip connections without using pre-trained weights,
# mIoU = 0.36

# %% [markdown]
# ### With --load_pretrained
#
# When properly configured using pre-trained weights should result in higher mIoUs. You can expect mIoU around .65

# %%
# !python main.py --skip concat --coco_path "{PATH_TO_COCO}"  --load_pretrained
# Out:
# device cuda
# Namespace(coco_path='/gdrive/My Drive/CSE527/Segireddy_RutwikReddy_115936140_hw3/coco/', batch_size=20, epochs=20, eval=False, load_pretrained=True, skip='concat', checkpoint='concat_checkpoint.pth')
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100% 44.7M/44.7M [00:00<00:00, 101MB/s]
# loading annotations into memory...
# Done (t=0.05s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.01s)
# creating index...
# index created!
# Epoch: [0]  [ 0/25]  eta: 0:01:00    time: 2.4106  data: 0.7231  max mem: 818
# Epoch: [0]  [10/25]  eta: 0:00:10    time: 0.7215  data: 0.5174  max mem: 926
# Epoch: [0]  [20/25]  eta: 0:00:03    time: 0.6048  data: 0.5471  max mem: 927
# Epoch: [0]  [24/25]  eta: 0:00:00    time: 0.6521  data: 0.5945  max mem: 927
# Epoch: [0] Total time: 0:00:17 (0.7073 s / it)
# train: dice: 0.740373, bce: 0.404225, loss: 0.515153
# saving best model to concat_checkpoint.pth
# 0m 17s
# Epoch: [7]  [ 0/25]  eta: 0:00:15    time: 0.6157  data: 0.5450  max mem: 928
# Epoch: [7]  [10/25]  eta: 0:00:09    time: 0.6330  data: 0.5771  max mem: 928
# Epoch: [7]  [20/25]  eta: 0:00:03    time: 0.6563  data: 0.6023  max mem: 928
# Epoch: [7]  [24/25]  eta: 0:00:00    time: 0.6500  data: 0.5959  max mem: 928
# Epoch: [7] Total time: 0:00:15 (0.6358 s / it)
# train: dice: 0.382210, bce: 0.160539, loss: 0.233690
# LR 0.0005
# Epoch: [7]  [0/3]  eta: 0:00:00    time: 0.3323  data: 0.2815  max mem: 928
# Epoch: [7]  [2/3]  eta: 0:00:00    time: 0.2674  data: 0.2230  max mem: 928
# Epoch: [7] Total time: 0:00:00 (0.2678 s / it)
# val: dice: 0.370552, bce: 0.158981, loss: 0.228800, mIoU: 0.597370, mDice: 0.709399
# saving best model to concat_checkpoint.pth
# 0m 17s
# Epoch: [8]  [ 0/25]  eta: 0:00:14    time: 0.5904  data: 0.5365  max mem: 928
# Epoch: [8]  [10/25]  eta: 0:00:10    time: 0.6764  data: 0.6178  max mem: 928
# Epoch: [8]  [20/25]  eta: 0:00:03    time: 0.6594  data: 0.6017  max mem: 928
# Epoch: [8]  [24/25]  eta: 0:00:00    time: 0.6620  data: 0.6056  max mem: 928
# Epoch: [8] Total time: 0:00:16 (0.6425 s / it)
# train: dice: 0.375910, bce: 0.158388, loss: 0.230170
# LR 0.0005
# Epoch: [8]  [0/3]  eta: 0:00:00    time: 0.3234  data: 0.2733  max mem: 928
# Epoch: [8]  [2/3]  eta: 0:00:00    time: 0.2558  data: 0.2103  max mem: 928
# Epoch: [8] Total time: 0:00:00 (0.2562 s / it)
# val: dice: 0.397833, bce: 0.166784, loss: 0.243030, mIoU: 0.553939, mDice: 0.666292
# 0m 17s
# Epoch: [9]  [ 0/25]  eta: 0:00:14    time: 0.5858  data: 0.5204  max mem: 928
# Epoch: [9]  [10/25]  eta: 0:00:10    time: 0.6914  data: 0.6317  max mem: 928
# Epoch: [9]  [20/25]  eta: 0:00:03    time: 0.6447  data: 0.5881  max mem: 928
# Epoch: [9]  [24/25]  eta: 0:00:00    time: 0.6452  data: 0.5898  max mem: 928
# Epoch: [9] Total time: 0:00:15 (0.6258 s / it)
# train: dice: 0.354697, bce: 0.147576, loss: 0.215926
# LR 0.0005
# Epoch: [9]  [0/3]  eta: 0:00:00    time: 0.3230  data: 0.2744  max mem: 928
# Epoch: [9]  [2/3]  eta: 0:00:00    time: 0.2563  data: 0.2140  max mem: 928
# Epoch: [9] Total time: 0:00:00 (0.2566 s / it)
# val: dice: 0.383010, bce: 0.154252, loss: 0.229742, mIoU: 0.590974, mDice: 0.702934
# 0m 16s
# Epoch: [10]  [ 0/25]  eta: 0:00:15    time: 0.6266  data: 0.5577  max mem: 928
# Epoch: [16]  [2/3]  eta: 0:00:00    time: 0.2465  data: 0.2048  max mem: 928
# Epoch: [16] Total time: 0:00:00 (0.2468 s / it)
# val: dice: 0.366859, bce: 0.148807, loss: 0.220764, mIoU: 0.585448, mDice: 0.692541
# 0m 16s
# Epoch: [17]  [ 0/25]  eta: 0:00:13    time: 0.5224  data: 0.4707  max mem: 928
# Epoch: [17]  [10/25]  eta: 0:00:10    time: 0.6873  data: 0.6281  max mem: 928
# Epoch: [17]  [20/25]  eta: 0:00:03    time: 0.6347  data: 0.5762  max mem: 928
# Epoch: [17]  [24/25]  eta: 0:00:00    time: 0.6259  data: 0.5668  max mem: 928
# Epoch: [17] Total time: 0:00:15 (0.6127 s / it)
# train: dice: 0.306987, bce: 0.124931, loss: 0.185009
# LR 0.0005
# Epoch: [17]  [0/3]  eta: 0:00:00    time: 0.3088  data: 0.2581  max mem: 928
# Epoch: [17]  [2/3]  eta: 0:00:00    time: 0.2523  data: 0.2078  max mem: 928
# Epoch: [17] Total time: 0:00:00 (0.2526 s / it)
# val: dice: 0.414823, bce: 0.184818, loss: 0.260720, mIoU: 0.514441, mDice: 0.629158
# 0m 16s
# Epoch: [18]  [ 0/25]  eta: 0:00:13    time: 0.5250  data: 0.4711  max mem: 928
# Epoch: [18]  [10/25]  eta: 0:00:10    time: 0.6829  data: 0.6269  max mem: 928
# Epoch: [18]  [20/25]  eta: 0:00:03    time: 0.6340  data: 0.5786  max mem: 928
# Epoch: [18]  [24/25]  eta: 0:00:00    time: 0.6261  data: 0.5710  max mem: 928
# Epoch: [18] Total time: 0:00:15 (0.6143 s / it)
# train: dice: 0.296297, bce: 0.120304, loss: 0.178382
# LR 0.0005
# Epoch: [18]  [0/3]  eta: 0:00:00    time: 0.3254  data: 0.2771  max mem: 928
# Epoch: [18]  [2/3]  eta: 0:00:00    time: 0.2557  data: 0.2133  max mem: 928
# Epoch: [18] Total time: 0:00:00 (0.2561 s / it)
# val: dice: 0.405647, bce: 0.194438, loss: 0.264137, mIoU: 0.536166, mDice: 0.654426
# 0m 16s
# Epoch: [19]  [ 0/25]  eta: 0:00:14    time: 0.5708  data: 0.4981  max mem: 928
# Epoch: [19]  [10/25]  eta: 0:00:10    time: 0.7109  data: 0.6543  max mem: 928
# Epoch: [19]  [20/25]  eta: 0:00:03    time: 0.6413  data: 0.5874  max mem: 928
# Epoch: [19]  [24/25]  eta: 0:00:00    time: 0.6303  data: 0.5767  max mem: 928
# Epoch: [19] Total time: 0:00:15 (0.6206 s / it)
# train: dice: 0.299133, bce: 0.121175, loss: 0.179901
# LR 5e-05
# Epoch: [19]  [0/3]  eta: 0:00:00    time: 0.3102  data: 0.2607  max mem: 928
# Epoch: [19]  [2/3]  eta: 0:00:00    time: 0.2499  data: 0.2066  max mem: 928
# Epoch: [19] Total time: 0:00:00 (0.2503 s / it)
# val: dice: 0.354818, bce: 0.185750, loss: 0.241542, mIoU: 0.591372, mDice: 0.702736
# 0m 16s
# Best val loss: 0.220739

# %%
# !python main.py --skip concat --coco_path "{PATH_TO_COCO}" --eval
# Out:
# device cuda
# Namespace(coco_path='/gdrive/My Drive/CSE527/Segireddy_RutwikReddy_115936140_hw3/coco/', batch_size=20, epochs=20, eval=True, load_pretrained=False, skip='concat', checkpoint='concat_checkpoint.pth')
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# loading annotations into memory...
# Done (t=0.01s)
# creating index...
# index created!
# Performance on validation dataset: mIoU:0.5975950956344604 , mDice:0.7106727957725525

# %% [markdown]
# For concatenation skip connections using pre-trained weights,
# mIoU = 0.60

# %% [markdown]
# Let us see the masks generated by the best run:
# It is okay if the masks are not perfectly aligned. We are only training over 500 images for a short duration!

# %%
folder_path = 'images'
show_images(folder_path)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# ##Implement SumUNet (10 points)
# ---
# This is very much similar to above UNet, but for the skip connections we will be using summation operation instead of concatenation. This is kind of an open ended question, in the sense that there are multuple ways you can design connections.
#
# Feel free to use any layers | blocks | up/down sampling.
#
#
# Hint:
# - Again you need to focus on the feature shapes
# - you can use sampling techniques to change the height/width
# - you can use conv layers to change number of channels
#
# Note: You can chose to remove --load_pretrained from the below cell if you think that will have a better perfromance

# %%
# !python main.py --skip sum --coco_path "{PATH_TO_COCO}"  --load_pretrained
# Out:
# device cuda
# Namespace(coco_path='/gdrive/My Drive/CSE527/Segireddy_RutwikReddy_115936140_hw3/coco/', batch_size=20, epochs=20, eval=False, load_pretrained=True, skip='sum', checkpoint='sum_checkpoint.pth')
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100% 44.7M/44.7M [00:00<00:00, 146MB/s]
# loading annotations into memory...
# Done (t=0.57s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.19s)
# creating index...
# index created!
# Epoch: [0]  [ 0/25]  eta: 0:06:45    time: 16.2124  data: 8.2472  max mem: 760
# Epoch: [0]  [10/25]  eta: 0:01:29    time: 5.9866  data: 5.1995  max mem: 845
# Epoch: [0]  [20/25]  eta: 0:00:27    time: 5.0567  data: 4.9879  max mem: 845
# Epoch: [0]  [24/25]  eta: 0:00:05    time: 5.1192  data: 5.0504  max mem: 845
# Epoch: [0] Total time: 0:02:18 (5.5443 s / it)
# train: dice: 0.815035, bce: 0.447380, loss: 0.568706
# LR 0.0005
# Epoch: [0]  [0/3]  eta: 0:00:19    time: 6.4285  data: 6.3487  max mem: 845
# Epoch: [0]  [2/3]  eta: 0:00:04    time: 4.4916  data: 4.4269  max mem: 845
# Epoch: [0] Total time: 0:00:13 (4.4919 s / it)
# val: dice: 0.633938, bce: 0.417598, loss: 0.488991, mIoU: 0.313634, mDice: 0.434740
# saving best model to sum_checkpoint.pth
# 2m 32s
# Epoch: [1]  [ 0/25]  eta: 0:00:14    time: 0.5745  data: 0.5067  max mem: 845
# Epoch: [1]  [10/25]  eta: 0:00:08    time: 0.5502  data: 0.4924  max mem: 847
# Epoch: [1]  [20/25]  eta: 0:00:03    time: 0.6225  data: 0.5629  max mem: 847
# Epoch: [1]  [24/25]  eta: 0:00:00    time: 0.6663  data: 0.6068  max mem: 847
# Epoch: [1] Total time: 0:00:16 (0.6470 s / it)
# train: dice: 0.650293, bce: 0.281158, loss: 0.402972
# LR 0.0005
# Epoch: [8]  [10/25]  eta: 0:00:09    time: 0.6424  data: 0.5854  max mem: 847
# Epoch: [8]  [20/25]  eta: 0:00:03    time: 0.6722  data: 0.6149  max mem: 847
# Epoch: [8]  [24/25]  eta: 0:00:00    time: 0.6721  data: 0.6141  max mem: 847
# Epoch: [8] Total time: 0:00:16 (0.6542 s / it)
# train: dice: 0.517887, bce: 0.213357, loss: 0.313852
# LR 0.0005
# Epoch: [8]  [0/3]  eta: 0:00:01    time: 0.3398  data: 0.2759  max mem: 847
# Epoch: [8]  [2/3]  eta: 0:00:00    time: 0.2747  data: 0.2186  max mem: 847
# Epoch: [8] Total time: 0:00:00 (0.2751 s / it)
# val: dice: 0.568621, bce: 0.227177, loss: 0.339853, mIoU: 0.362634, mDice: 0.477041
# 0m 17s
# Epoch: [9]  [ 0/25]  eta: 0:00:15    time: 0.6025  data: 0.5358  max mem: 847
# Epoch: [9]  [10/25]  eta: 0:00:10    time: 0.7062  data: 0.6464  max mem: 847
# Epoch: [9]  [20/25]  eta: 0:00:03    time: 0.6893  data: 0.6306  max mem: 847
# Epoch: [9]  [24/25]  eta: 0:00:00    time: 0.6904  data: 0.6321  max mem: 847
# Epoch: [9] Total time: 0:00:16 (0.6660 s / it)
# train: dice: 0.514799, bce: 0.209471, loss: 0.310229
# LR 0.0005
# Epoch: [9]  [0/3]  eta: 0:00:01    time: 0.3347  data: 0.2707  max mem: 847
# Epoch: [9]  [2/3]  eta: 0:00:00    time: 0.2739  data: 0.2172  max mem: 847
# Epoch: [9] Total time: 0:00:00 (0.2743 s / it)
# val: dice: 0.553721, bce: 0.298024, loss: 0.382404, mIoU: 0.407677, mDice: 0.535997
# 0m 17s
# Epoch: [10]  [ 0/25]  eta: 0:00:15    time: 0.6012  data: 0.5330  max mem: 847
# Epoch: [10]  [10/25]  eta: 0:00:10    time: 0.6906  data: 0.6305  max mem: 847
# Epoch: [10]  [20/25]  eta: 0:00:03    time: 0.6545  data: 0.5957  max mem: 847
# Epoch: [10]  [24/25]  eta: 0:00:00    time: 0.6552  data: 0.5968  max mem: 847
# Epoch: [10] Total time: 0:00:15 (0.6356 s / it)
# train: dice: 0.502664, bce: 0.208262, loss: 0.305414
# LR 0.0005
# Epoch: [10]  [0/3]  eta: 0:00:00    time: 0.3281  data: 0.2764  max mem: 847
# Epoch: [10]  [2/3]  eta: 0:00:00    time: 0.2694  data: 0.2224  max mem: 847
# Epoch: [10] Total time: 0:00:00 (0.2698 s / it)
# val: dice: 0.522939, bce: 0.220909, loss: 0.320579, mIoU: 0.426426, mDice: 0.551654
# saving best model to sum_checkpoint.pth
# 0m 17s
# Epoch: [11]  [ 0/25]  eta: 0:00:15    time: 0.6264  data: 0.5582  max mem: 847
# Epoch: [11]  [10/25]  eta: 0:00:10    time: 0.7165  data: 0.6562  max mem: 847
# Epoch: [11]  [20/25]  eta: 0:00:03    time: 0.6783  data: 0.6200  max mem: 847
# Epoch: [11]  [24/25]  eta: 0:00:00    time: 0.6739  data: 0.6144  max mem: 847
# Epoch: [11] Total time: 0:00:16 (0.6567 s / it)
# train: dice: 0.487145, bce: 0.200751, loss: 0.295261
# LR 0.0005
# Epoch: [11]  [0/3]  eta: 0:00:01    time: 0.3406  data: 0.2884  max mem: 847
# Epoch: [11]  [2/3]  eta: 0:00:00    time: 0.2628  data: 0.2173  max mem: 847
# Epoch: [11] Total time: 0:00:00 (0.2632 s / it)
# val: dice: 0.518451, bce: 0.225294, loss: 0.322036, mIoU: 0.450252, mDice: 0.579553
# 0m 17s
# Epoch: [12]  [ 0/25]  eta: 0:00:14    time: 0.5710  data: 0.5159  max mem: 847
# Epoch: [12]  [10/25]  eta: 0:00:11    time: 0.7513  data: 0.6926  max mem: 847
# Epoch: [12]  [20/25]  eta: 0:00:03    time: 0.6637  data: 0.6065  max mem: 847
# Epoch: [12]  [24/25]  eta: 0:00:00    time: 0.6395  data: 0.5823  max mem: 847
# Epoch: [12] Total time: 0:00:16 (0.6430 s / it)
# train: dice: 0.470472, bce: 0.186768, loss: 0.280391
# LR 0.0005
# Epoch: [12]  [0/3]  eta: 0:00:00    time: 0.3273  data: 0.2758  max mem: 847
# Epoch: [12]  [2/3]  eta: 0:00:00    time: 0.2803  data: 0.2328  max mem: 847
# Epoch: [12] Total time: 0:00:00 (0.2808 s / it)
# val: dice: 0.552629, bce: 0.210692, loss: 0.323531, mIoU: 0.390718, mDice: 0.503424
# 0m 17s
# Epoch: [13]  [ 0/25]  eta: 0:00:15    time: 0.6214  data: 0.5671  max mem: 847
# Epoch: [13]  [10/25]  eta: 0:00:11    time: 0.7658  data: 0.7070  max mem: 847
# Epoch: [13]  [20/25]  eta: 0:00:03    time: 0.6786  data: 0.6202  max mem: 847
# Epoch: [13]  [24/25]  eta: 0:00:00    time: 0.6351  data: 0.5765  max mem: 847
# Epoch: [13] Total time: 0:00:16 (0.6574 s / it)
# train: dice: 0.462697, bce: 0.185639, loss: 0.277068
# LR 0.0005
# Epoch: [13]  [0/3]  eta: 0:00:01    time: 0.3584  data: 0.3067  max mem: 847
# Epoch: [13]  [2/3]  eta: 0:00:00    time: 0.2738  data: 0.2290  max mem: 847
# Epoch: [13] Total time: 0:00:00 (0.2742 s / it)
# val: dice: 0.489437, bce: 0.243631, loss: 0.324747, mIoU: 0.440835, mDice: 0.566104
# 0m 17s
# Epoch: [14]  [ 0/25]  eta: 0:00:15    time: 0.6342  data: 0.5781  max mem: 847
# Epoch: [14]  [10/25]  eta: 0:00:11    time: 0.7428  data: 0.6816  max mem: 847
# Epoch: [14]  [20/25]  eta: 0:00:03    time: 0.6613  data: 0.6018  max mem: 847
# Epoch: [14]  [24/25]  eta: 0:00:00    time: 0.6092  data: 0.5508  max mem: 847
# Epoch: [14] Total time: 0:00:16 (0.6442 s / it)
# train: dice: 0.446385, bce: 0.181461, loss: 0.268886
# LR 0.0005
# Epoch: [14]  [0/3]  eta: 0:00:00    time: 0.3223  data: 0.2676  max mem: 847
# saving best model to sum_checkpoint.pth
# 0m 17s
# Epoch: [18]  [ 0/25]  eta: 0:00:21    time: 0.8498  data: 0.7795  max mem: 847
# Epoch: [18]  [10/25]  eta: 0:00:10    time: 0.6675  data: 0.6100  max mem: 847
# Epoch: [18]  [20/25]  eta: 0:00:03    time: 0.6131  data: 0.5569  max mem: 847
# Epoch: [18]  [24/25]  eta: 0:00:00    time: 0.6019  data: 0.5443  max mem: 847
# Epoch: [18] Total time: 0:00:16 (0.6427 s / it)
# train: dice: 0.409385, bce: 0.164703, loss: 0.245448
# LR 0.0005
# Epoch: [18]  [0/3]  eta: 0:00:01    time: 0.4367  data: 0.3711  max mem: 847
# Epoch: [18]  [2/3]  eta: 0:00:00    time: 0.3544  data: 0.2967  max mem: 847
# Epoch: [18] Total time: 0:00:01 (0.3549 s / it)
# val: dice: 0.488852, bce: 0.200867, loss: 0.295902, mIoU: 0.449540, mDice: 0.567041
# 0m 17s
# Epoch: [19]  [ 0/25]  eta: 0:00:20    time: 0.8348  data: 0.7648  max mem: 847
# Epoch: [19]  [10/25]  eta: 0:00:09    time: 0.6511  data: 0.5924  max mem: 847
# Epoch: [19]  [20/25]  eta: 0:00:03    time: 0.5912  data: 0.5347  max mem: 847
# Epoch: [19]  [24/25]  eta: 0:00:00    time: 0.6086  data: 0.5507  max mem: 847
# Epoch: [19] Total time: 0:00:15 (0.6348 s / it)
# train: dice: 0.376168, bce: 0.154389, loss: 0.227576
# LR 5e-05
# Epoch: [19]  [0/3]  eta: 0:00:01    time: 0.4523  data: 0.3995  max mem: 847
# Epoch: [19]  [2/3]  eta: 0:00:00    time: 0.3603  data: 0.3134  max mem: 847
# Epoch: [19] Total time: 0:00:01 (0.3608 s / it)
# val: dice: 0.442164, bce: 0.218632, loss: 0.292398, mIoU: 0.499983, mDice: 0.621471
# saving best model to sum_checkpoint.pth
# 0m 17s
# Best val loss: 0.292398

# %%
# !python main.py --skip sum --coco_path "{PATH_TO_COCO}"  --eval
# Out:
# device cuda
# Namespace(coco_path='/gdrive/My Drive/CSE527/Segireddy_RutwikReddy_115936140_hw3/coco/', batch_size=20, epochs=20, eval=True, load_pretrained=False, skip='sum', checkpoint='sum_checkpoint.pth')
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# loading annotations into memory...
# Done (t=0.01s)
# creating index...
# index created!
# Performance on validation dataset: mIoU:0.4999825954437256 , mDice:0.6214714050292969

# %% [markdown]
# For summation skip connections, mIoU = 0.50

# %% [markdown]
# ## Submission guidelines
# ---
#
#
#
# The submission structure should look like:
#
# IMPORTANT: Remove the images/ folder, and any CHECKPOINT files.
#
#
# ```
# {last name}_{first name}_{sbu id}_hw2/
# ├── part1/
# │   └── ...
# ├── part2/
# │   └── ...
# ├── part3/
# │   ├── CSE527_23F_HW3_P3.ipynb
# │   └── unet/
# │       ├── utils/
# │       │   ├── ...
# │       │   └── ...
# │       ├── coco.py
# │       ├── main.py
# │       ├── transforms.py
# │       └── unet.py
# ```
#
#
# Follow instructions in part1's submission guidelines to generate your complete submission
